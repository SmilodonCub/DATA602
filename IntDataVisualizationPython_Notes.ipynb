# %% [markdown]
# # Introduction to Data Visualization in Python
# Notes from DataCamp

# %% [markdown]
# ## Customizing Plots

# %% [markdown]
# ### Plotting Multiple Graphs

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
noaa_url = 'https://raw.githubusercontent.com/SmilodonCub/DATA602/master/NOAAdat.csv'
noaa_df = pd.read_csv( noaa_url )
noaa_df.head( 5 )
# Out:
#              STATION                STATION_NAME      DATE  DLY-CLDD-BASE45  \
# 0  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20100101            -7777
# 1  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20100102            -7777
# 2  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20100103            -7777
# 3  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20100104            -7777
# 4  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20100105            -7777
#
#    DLY-CLDD-BASE50  DLY-CLDD-BASE55  DLY-CLDD-BASE57  DLY-CLDD-BASE60  \
# 0            -7777            -7777            -7777            -7777
# 1            -7777            -7777            -7777            -7777
# 2            -7777            -7777            -7777            -7777
# 3            -7777            -7777            -7777            -7777
# 4            -7777            -7777            -7777            -7777
#
#    DLY-CLDD-NORMAL  DLY-CLDD-BASE70  ...  DLY-SNOW-PCTALL-GE030TI  \
# ...

# %%
noaa_df.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'DATE', 'DLY-CLDD-BASE45', 'DLY-CLDD-BASE50',
#        'DLY-CLDD-BASE55', 'DLY-CLDD-BASE57', 'DLY-CLDD-BASE60',
#        'DLY-CLDD-NORMAL', 'DLY-CLDD-BASE70', 'DLY-CLDD-BASE72',
#        'DLY-HTDD-BASE40', 'DLY-HTDD-BASE45', 'DLY-HTDD-BASE50',
#        'DLY-HTDD-BASE55', 'DLY-HTDD-BASE57', 'DLY-HTDD-BASE60',
#        'DLY-HTDD-NORMAL', 'DLY-PRCP-25PCTL', 'DLY-SNWD-25PCTL',
#        'DLY-SNOW-25PCTL', 'DLY-PRCP-50PCTL', 'DLY-SNWD-50PCTL',
#        'DLY-SNOW-50PCTL', 'DLY-PRCP-75PCTL', 'DLY-SNWD-75PCTL',
#        'DLY-SNOW-75PCTL', 'MTD-PRCP-NORMAL', 'MTD-SNOW-NORMAL',
#        'YTD-PRCP-NORMAL', 'YTD-SNOW-NORMAL', 'DLY-PRCP-PCTALL-GE001HI',
#        'DLY-PRCP-PCTALL-GE010HI', 'DLY-PRCP-PCTALL-GE050HI',
#        'DLY-PRCP-PCTALL-GE100HI', 'DLY-SNWD-PCTALL-GE001WI',
#        'DLY-SNWD-PCTALL-GE010WI', 'DLY-SNWD-PCTALL-GE003WI',
#        'DLY-SNWD-PCTALL-GE005WI', 'DLY-SNOW-PCTALL-GE001TI',
#        'DLY-SNOW-PCTALL-GE010TI', 'DLY-SNOW-PCTALL-GE100TI',
# ...

# %%
noaa_df = noaa_df[ [ 'DATE', 'DLY-TAVG-NORMAL', 'DLY-TMAX-NORMAL', 'DLY-TMIN-NORMAL' ] ]
noaa_df.head()
# Out:
#        DATE  DLY-TAVG-NORMAL  DLY-TMAX-NORMAL  DLY-TMIN-NORMAL
# 0  20100101             33.4             38.9             27.9
# 1  20100102             33.3             38.8             27.7
# 2  20100103             33.1             38.7             27.6
# 3  20100104             33.0             38.5             27.4
# 4  20100105             32.9             38.4             27.3

# %%
noaa_df.dtypes
# Out:
# DATE                 int64
# DLY-TAVG-NORMAL    float64
# DLY-TMAX-NORMAL    float64
# DLY-TMIN-NORMAL    float64
# dtype: object

# %%
noaa_df['DATE'] = pd.to_datetime(noaa_df['DATE'].astype(str), format='%Y%m%d')
# Out:
# /home/bonzilla/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print( noaa_df.dtypes )
noaa_df.head()
# Out:
# DATE               datetime64[ns]
# DLY-TAVG-NORMAL           float64
# DLY-TMAX-NORMAL           float64
# DLY-TMIN-NORMAL           float64
# dtype: object
#         DATE  DLY-TAVG-NORMAL  DLY-TMAX-NORMAL  DLY-TMIN-NORMAL
# 0 2010-01-01             33.4             38.9             27.9
# 1 2010-01-02             33.3             38.8             27.7
# 2 2010-01-03             33.1             38.7             27.6
# 3 2010-01-04             33.0             38.5             27.4
# 4 2010-01-05             32.9             38.4             27.3

# %%
plt.plot( noaa_df['DATE'], noaa_df['DLY-TAVG-NORMAL'], 'k.' )
plt.plot( noaa_df['DATE'], noaa_df['DLY-TMAX-NORMAL'], 'r.' )
plt.plot( noaa_df['DATE'], noaa_df['DLY-TMIN-NORMAL'], 'b.' )
plt.xlabel( 'Date' )
plt.title( 'Temperature in Central Park' )
plt.show()

# %%
print( noaa_df.shape )
len( set( noaa_df['DATE']))
# Out:
# (3285, 4)
# 365

# %%
noaa_gbdate = noaa_df.groupby( 'DATE' ).mean()
noaa_gbdate.head()
# Out:
#             DLY-TAVG-NORMAL  DLY-TMAX-NORMAL  DLY-TMIN-NORMAL
# DATE
# 2010-01-01        33.244444        39.577778        26.933333
# 2010-01-02        33.088889        39.411111        26.766667
# 2010-01-03        32.944444        39.277778        26.588889
# 2010-01-04        32.788889        39.144444        26.444444
# 2010-01-05        32.677778        39.033333        26.288889

# %%
plt.plot( noaa_gbdate['DLY-TAVG-NORMAL'], 'k.' )
plt.plot( noaa_gbdate['DLY-TMAX-NORMAL'], 'r.' )
plt.plot( noaa_gbdate['DLY-TMIN-NORMAL'], 'b.' )
plt.xlabel( 'Date' )
plt.title( 'Temperature in Central Park' )
plt.show()

# %% [markdown]
# Make some subplots using the `axes()` command
# * syntax: `axes( [ x_lo, y_lo, width, height ] )
# * units between 0 and 1 (figure dimensions)
#
# it's kinda tricky to get the dimentions right. just need to play with it!

# %%
#plot data in different axes (subplots)
plt.axes( [ 0.05, 0.05, 0.425, 0.9 ] )
plt.plot( noaa_gbdate['DLY-TMAX-NORMAL'], 'r' )
plt.xlabel( 'Date' )
plt.title( 'Max Temp in Central Park' )
plt.axes( [ 0.525, 0.05, 0.425, 0.9 ] )
plt.plot( noaa_gbdate['DLY-TMIN-NORMAL'], 'b' )
plt.xlabel( 'Date' )
plt.title( 'Min Temp in Central Park' )
plt.show()

# %% [markdown]
# The `subplot()` function figures out a grid of axes, so that the user doesn't have to do that manually. However, this is more rigid than the `axes()` method.
# * syntax: `subplot( nrows, ncols, nsubplot )
# * subplot ordering:
#     + row-wise from top left
#     + indexed from 1

# %%
plt.subplot( 1,3,1 )
plt.plot( noaa_gbdate['DLY-TMAX-NORMAL'], 'r' )
plt.xlabel( 'Date' )
plt.title( 'Max Temp' )
plt.subplot( 1,3,3 )
plt.plot( noaa_gbdate['DLY-TMIN-NORMAL'], 'b' )
plt.xlabel( 'Date' )
plt.title( 'Min Temp' )
plt.subplot( 1,3,2 )
plt.plot( noaa_gbdate['DLY-TAVG-NORMAL'], 'k' )
plt.xlabel( 'Date' )
plt.title( 'Avg Temp' )
plt.show()

# %%
physical_sciences = np.array( [ 13.8, 14.9, 14.8, 16.5, 18.2, 19.1, 20.,  21.3, 22.5, 23.7, 24.6, 25.7, 27.3, 27.6, 
                              28.,  27.5, 28.4, 30.4, 29.7, 31.3, 31.6, 32.6, 32.6, 33.6, 34.8, 35.9, 37.3, 38.3,
                              39.7, 40.2, 41.,  42.2, 41.1, 41.7, 42.1, 41.6, 40.8, 40.7, 40.7, 40.7, 40.2, 40.1 ] )
year = np.array( [ 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
                  1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 
                  2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011 ] )
computer_science = np.array( [ 13.6, 13.6, 14.9, 16.4, 18.9, 19.8, 23.9, 25.7, 28.1, 30.2, 32.5, 34.8, 36.3, 37.1, 
                              36.8, 35.7, 34.7, 32.4, 30.8, 29.9, 29.4, 28.7, 28.2, 28.5, 28.5, 27.5, 27.1, 26.8, 
                              27., 28.1, 27.7, 27.6, 27., 25.1, 22.2, 20.6, 18.6, 17.6, 17.8, 18.1, 17.6, 18.2 ] )

degrees_df = pd.DataFrame( { 'PhysSci' : physical_sciences, 'CompSci' : computer_science, 'Year' : year } )
degrees_df.head()
# Out:
#    PhysSci  CompSci  Year
# 0     13.8     13.6  1970
# 1     14.9     13.6  1971
# 2     14.8     14.9  1972
# 3     16.5     16.4  1973
# 4     18.2     18.9  1974

# %%
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'PhysSci'], 'b', label='PhysSci' )
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'CompSci'], 'r', label='CompSci' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( '% Degrees Awarded to Women' )
plt.legend()
plt.show()

# %%
plt.axes([0.05, 0.05, 0.425, 0.9])
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'PhysSci'], 'b', label='PhysSci' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( 'Physical Sciences' )
plt.legend()
plt.axes([0.525, 0.05, 0.425, 0.9])
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'CompSci'], 'r', label='CompSci' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( 'Computer Sciences' )
plt.legend()
plt.show()

# %%
plt.subplot( 1,2,1 )
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'PhysSci'], 'b', label='PhysSci' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( 'Physical Sciences' )
plt.legend()
plt.subplot( 1,2,2 )
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'CompSci'], 'r', label='CompSci' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( 'Computer Sciences' )
plt.legend()
plt.tight_layout()
plt.show()

# %%
education = np.array( [74.53532758, 74.14920369, 73.55451996, 73.50181443, 73.33681143, 72.80185448, 
                       72.16652471, 72.45639481, 73.19282134, 73.82114234, 74.98103152, 75.84512345, 
                       75.84364914, 75.95060123, 75.86911601, 75.92343971, 76.14301516, 76.96309168,
                       77.62766177, 78.11191872, 78.86685859, 78.99124597, 78.43518191, 77.26731199,
                       75.81493264, 75.12525621, 75.03519921, 75.1637013, 75.48616027, 75.83816206,
                       76.69214284, 77.37522931, 78.64424394, 78.54494815, 78.65074774, 79.06712173,
                       78.68630551, 78.72141311, 79.19632674, 79.5329087,  79.61862451, 79.43281184 ] )
healthprof = np.array( [77.1, 75.5, 76.9, 77.4, 77.9, 78.9, 79.2, 80.5, 81.9, 82.3, 83.5, 84.1, 84.4, 84.6,
                        85.1, 85.3, 85.7, 85.5, 85.2, 84.6, 83.9, 83.5, 83.,  82.4, 81.8, 81.5, 81.3, 81.9,
                        82.1, 83.5, 83.5, 85.1, 85.8, 86.5, 86.5, 86.,  85.9, 85.4, 85.2, 85.1, 85.,  84.8 ] )
degrees_df[ 'Education' ] = education
degrees_df[ 'Health' ] = healthprof
degrees_df.head()
# Out:
#    PhysSci  CompSci  Year  Education  Health
# 0     13.8     13.6  1970  74.535328    77.1
# 1     14.9     13.6  1971  74.149204    75.5
# 2     14.8     14.9  1972  73.554520    76.9
# 3     16.5     16.4  1973  73.501814    77.4
# 4     18.2     18.9  1974  73.336811    77.9

# %%
plt.subplot( 2,2,1 )
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'PhysSci'], 'b', label='PhysSci' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( 'Physical Sciences' )
plt.legend()
plt.subplot( 2,2,2 )
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'CompSci'], 'r', label='CompSci' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( 'Computer Sciences' )
plt.legend()
plt.tight_layout()
plt.subplot( 2,2,3 )
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'Health'], 'g', label='Health' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( 'Health Profession' )
plt.legend()
plt.subplot( 2,2,4 )
plt.plot( degrees_df[ 'Year' ], degrees_df[ 'Education'], 'c', label='Education' )
plt.xlabel( 'Year' )
plt.ylabel( '%' )
plt.title( 'Education' )
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Customizing Axes

# %% [markdown]
# Controlling axis extents
# * `axis( [ xmin, xmax, ymin, ymax ] )`
# * or control individual axis extants:
#     + `xlim( [ xmin, xmax ] )`
#     + `ylim( [ ymin, ymax ] )`
# * can use either tuples or lists:
#     + `xlim( ( -2,3 ) )` works
#     + `xlim( [ -2,3 ] )` works all the same

# %%
usgdp_url = 'https://raw.githubusercontent.com/SmilodonCub/DATA602/master/gdp_year.csv'
usgdp_df = pd.read_csv( usgdp_url )
usgdp_df.head()
# Out:
#    date  level-current  level-chained  change-current  change-chained
# 0  1930           92.2          966.7           -16.0            -6.4
# 1  1931           77.4          904.8           -23.1           -12.9
# 2  1932           59.5          788.2            -4.0            -1.3
# 3  1933           57.2          778.3            16.9            10.8
# 4  1934           66.8          862.2            11.1             8.9

# %%
#using xlim & ylim to subset the plot
plt.plot( usgdp_df[ 'date' ], usgdp_df[ 'level-current'] )
plt.xlabel( 'Year' )
plt.ylabel( 'Billions USD' )
plt.title( 'US Gross Domestic Product' )
plt.xlim( ( 1947, 1957 ) )
plt.ylim( ( 0, 1000 ) )
plt.show()

# %%
#a single call to .axis()
plt.plot( usgdp_df[ 'date' ], usgdp_df[ 'level-current'] )
plt.xlabel( 'Year' )
plt.ylabel( 'Billions USD' )
plt.title( 'US Gross Domestic Product' )
plt.axis( ( 1980, 2010, 0, 20000))
plt.show()

# %% [markdown]
# other `axis()` options:
# * `axis('off')` turns off axis lines, labels
# * `axis('equal')` equal scaling on x and y axis
# * `axis('square')` forces square plot
# * `axis('tight')` sets xlim, ylim to show all data

# %%
an = np.linspace( 0,2*np.pi, 100 )
fig, axs = plt.subplots( 3,2 )

axs[0, 0].plot(3 * np.cos(an), 3 * np.sin(an))
axs[0, 0].set_title('not equal, looks like ellipse', fontsize=10)

axs[0, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[0, 1].axis('equal')
axs[0, 1].set_title('equal, looks like circle', fontsize=10)

axs[1, 0].plot(3 * np.cos(an), 3 * np.sin(an))
axs[1, 0].axis('square')
axs[1, 0].set_title('still a circle, limits fit to data', fontsize=10)

axs[1, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[1, 1].axis('tight')
axs[1, 1].set_title('not a circle, limits fit to data', fontsize=10)

axs[2, 0].plot(3 * np.cos(an), 3 * np.sin(an))
axs[2, 0].axis('off')
axs[2, 0].set_title('axis off', fontsize=10)

axs[2, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[2, 1].set_aspect('equal', 'box')
axs[2, 1].axis('off')
axs[2, 1].set_title('axis off, circle again', fontsize=10)

fig.tight_layout()

plt.suptitle( 'Playing with axis()', y = 1.05)

plt.show()

# %% [markdown]
# ### Legends, Annotations and Styles

# %%
from sklearn.datasets import load_iris

# %%
iris_dat = load_iris() 
iris_df = pd.DataFrame( iris_dat.data, columns = iris_dat.feature_names )
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print( iris_dat.target_names )
print( set( iris_dat.target ) )
iris_df['target'] = iris_dat.target
iris_df.head()
# Out:
# ['setosa' 'versicolor' 'virginica']
# {0, 1, 2}
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
plt.subplot( 1,2,1 )
plt.scatter( iris_df[ iris_df['target']==0 ]['sepal length (cm)'],
            iris_df[ iris_df['target']==0 ]['sepal width (cm)'],
            marker='o', color = 'red', label='setosa' )
plt.scatter( iris_df[ iris_df['target']==1 ]['sepal length (cm)'],
            iris_df[ iris_df['target']==1 ]['sepal width (cm)'],
            marker='o', color = 'green', label='versicolor' )
plt.scatter( iris_df[ iris_df['target']==2 ]['sepal length (cm)'],
            iris_df[ iris_df['target']==2 ]['sepal width (cm)'],
            marker='o', color = 'blue', label='virginica' )
#plt.legend( loc = 'upper right' )
plt.title( 'Sepal dim' )
plt.xlabel( 'sepal length (cm)' )
plt.ylabel( 'sepal width (cm)' )
plt.xlim( ( 2,10 ) )
plt.ylim( ( 1,6 ) )

plt.subplot( 1,2,2 )
plt.scatter( iris_df[ iris_df['target']==0 ]['petal length (cm)'],
            iris_df[ iris_df['target']==0 ]['petal width (cm)'],
            marker='o', color = 'red', label='setosa' )
plt.scatter( iris_df[ iris_df['target']==1 ]['petal length (cm)'],
            iris_df[ iris_df['target']==1 ]['petal width (cm)'],
            marker='o', color = 'green', label='versicolor' )
plt.scatter( iris_df[ iris_df['target']==2 ]['petal length (cm)'],
            iris_df[ iris_df['target']==2 ]['petal width (cm)'],
            marker='o', color = 'blue', label='virginica' )
plt.legend( loc = 'upper right' )
plt.suptitle( 'Iris data' )
plt.title( 'Petal dim')
plt.xlabel( 'petal length (cm)' )
plt.ylabel( 'petal width (cm)' )
plt.xlim( ( 0,10 ) )
plt.ylim( ( 0,4 ) )

plt.show()

# %% [markdown]
# Plot Annotations
# * test labels and arrows using `annotate()` method
# * flexible specification of coordinates
# * keyword `arrowprops`:`dict` of arrow properties
#     + width
#     + color
#     + etc.

# %%
plt.scatter( iris_df[ iris_df['target']==0 ]['sepal length (cm)'],
            iris_df[ iris_df['target']==0 ]['sepal width (cm)'],
            marker='o', color = 'red', label='setosa' )
plt.scatter( iris_df[ iris_df['target']==1 ]['sepal length (cm)'],
            iris_df[ iris_df['target']==1 ]['sepal width (cm)'],
            marker='o', color = 'green', label='versicolor' )
plt.scatter( iris_df[ iris_df['target']==2 ]['sepal length (cm)'],
            iris_df[ iris_df['target']==2 ]['sepal width (cm)'],
            marker='o', color = 'blue', label='virginica' )
#plt.legend( loc = 'upper right' )
plt.title( 'Sepal dim' )
plt.xlabel( 'sepal length (cm)' )
plt.ylabel( 'sepal width (cm)' )
plt.xlim( ( 4,8.5 ) )
plt.ylim( ( 1.5,5 ) )
plt.annotate( 'setosa', xy = ( 5.0, 3.5 ), size = 20, color = 'red' )
plt.annotate( 'versicolor', xy = ( 7.25, 3.5 ), size = 20, color='blue' )
plt.annotate( 'virginica', xy = ( 5.0, 2.0 ), size = 20, color = 'green' )
plt.show()

# %%
plt.scatter( iris_df[ iris_df['target']==0 ]['petal length (cm)'],
            iris_df[ iris_df['target']==0 ]['petal width (cm)'],
            marker='o', color = 'red', label='setosa' )
plt.scatter( iris_df[ iris_df['target']==1 ]['petal length (cm)'],
            iris_df[ iris_df['target']==1 ]['petal width (cm)'],
            marker='o', color = 'green', label='versicolor' )
plt.scatter( iris_df[ iris_df['target']==2 ]['petal length (cm)'],
            iris_df[ iris_df['target']==2 ]['petal width (cm)'],
            marker='o', color = 'blue', label='virginica' )
plt.legend( loc = 'upper right' )
plt.title( 'Petal dim')
plt.xlabel( 'petal length (cm)' )
plt.ylabel( 'petal width (cm)' )
plt.xlim( ( 0,10 ) )
plt.ylim( ( 0,4 ) )
plt.annotate( 'setosa', xy = ( 1.5, 0.5 ), 
             size = 20, color = 'red',
             xytext = ( 0.5, 1.5 ),
             arrowprops={ 'color':'red','arrowstyle':"wedge" } )
plt.annotate( 'versicolor', xy = ( 4.0, 1.25 ), 
             size = 20, color='green',
             xytext = ( 7.0, 0.5 ),
             arrowprops={ 'color':'green','arrowstyle':"wedge" } )
plt.annotate( 'virginica', xy = ( 5.5, 2.0 ), 
             size = 20, color = 'blue', 
             xytext = ( 1.0, 3.0 ),
             arrowprops={ 'color':'blue','arrowstyle':"wedge" } )
plt.show()

# %% [markdown]
# Working with plot styles
# * style sheets in `matplotlib`
# * defaults for lines, points, backgrounds, etc.
# * switch styles globally with `plt.style.use()`
# * `plt.style.available`: list of styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use( 'fivethirtyeight' )
plt.scatter( iris_df[ iris_df['target']==0 ]['petal length (cm)'],
            iris_df[ iris_df['target']==0 ]['petal width (cm)'],
            marker='o', color = 'red', label='setosa' )
plt.scatter( iris_df[ iris_df['target']==1 ]['petal length (cm)'],
            iris_df[ iris_df['target']==1 ]['petal width (cm)'],
            marker='o', color = 'green', label='versicolor' )
plt.scatter( iris_df[ iris_df['target']==2 ]['petal length (cm)'],
            iris_df[ iris_df['target']==2 ]['petal width (cm)'],
            marker='o', color = 'blue', label='virginica' )
plt.legend( loc = 'upper right' )
plt.title( 'Petal dim')
plt.xlabel( 'petal length (cm)' )
plt.ylabel( 'petal width (cm)' )
plt.xlim( ( 0,10 ) )
plt.ylim( ( 0,4 ) )
plt.annotate( 'setosa', xy = ( 1.5, 0.5 ), 
             size = 20, color = 'red',
             xytext = ( 0.5, 1.5 ),
             arrowprops={ 'color':'red','arrowstyle':"wedge" } )
plt.annotate( 'versicolor', xy = ( 4.0, 1.25 ), 
             size = 20, color='green',
             xytext = ( 7.0, 0.5 ),
             arrowprops={ 'color':'green','arrowstyle':"wedge" } )
plt.annotate( 'virginica', xy = ( 5.5, 2.0 ), 
             size = 20, color = 'blue', 
             xytext = ( 1.0, 3.0 ),
             arrowprops={ 'color':'blue','arrowstyle':"wedge" } )
plt.show()

# %%
plt.style.use('seaborn-dark-palette')
fig1
plt.show()

# %% [markdown]
# ## Working with 2D Arrays

# %% [markdown]
# Refresher: NumPy Arrays
# * Homogeneous in data type
# * Supports vectorized calculations
# * Indexing with brackets:
#     + `A[ index ] for a 1D array
#     + `A[ index0, index1 ] for a 2D array
#
# Reminder: slicing arrays
# * slicing 1D arrays: `A[ index ]`, 2D arrays `A[ slice0, slice1 ]`
# * slicing: `slice = start:stop:stride`
# * indexes from `start` to `stop-1` in steps of `stride`
# * missing start: implies the start of the array
# * missing stop: implies the end of the array
# * missing stride: implies step of 1
# * negative indices/slices: count from end of array

# %%
u = np.linspace( -2,2,30 )
v = np.linspace( -1,1,50 )
X,Y = np.meshgrid( u,v )

Z= X**2/25 + Y**2/4

print( Z )
plt.set_cmap( 'gray' )
plt.pcolor( Z )
plt.show()
# Out:
# [[0.41       0.38869203 0.36890606 ... 0.36890606 0.38869203 0.41      ]
#  [0.39000833 0.36870036 0.34891439 ... 0.34891439 0.36870036 0.39000833]
#  [0.37084965 0.34954168 0.32975571 ... 0.32975571 0.34954168 0.37084965]
#  ...
#  [0.37084965 0.34954168 0.32975571 ... 0.32975571 0.34954168 0.37084965]
#  [0.39000833 0.36870036 0.34891439 ... 0.34891439 0.36870036 0.39000833]
#  [0.41       0.38869203 0.36890606 ... 0.36890606 0.38869203 0.41      ]]

# %%
# Import numpy and matplotlib.pyplot
import numpy as np
import matplotlib.pyplot as plt

# Generate two 1-D arrays: u, v
u = np.linspace(-2, 2, 41)
v = np.linspace(-1,1,21,)

# Generate 2-D arrays from u and v: X, Y
X,Y = np.meshgrid( u,v )

# Compute Z based on X and Y
Z = np.sin(3*np.sqrt(X**2 + Y**2)) 

# Display the resulting image with pcolor()
plt.pcolor( Z )
plt.show()

# %%
A = np.array([[1, 0, -1], [2, 0, 1], [1, 1, 1]])
plt.pcolor(A, cmap='Blues')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Visualizing Bivariate Functions

# %%
u = np.linspace( -2,2,65 )
v = np.linspace( -1,1,33 )
X,Y = np.meshgrid( u,v )

Z = np.cos(2*np.sqrt(X**2 + Y**2)) 


colormaps = [ 'inferno', 'magma', 'plasma', 'viridis' ]
for colormap in list( range( 4 ) ):
    #plt.plot( 4colormap+1 )
    plt.set_cmap( colormaps[ colormap ] )
    plt.pcolor( Z )
    plt.show()

# %%
#Pseudocolor plot
plt.pcolor( X,Y,Z, cmap= 'autumn' ) #axes are in terms of variable values instead of index
plt.colorbar()
plt.axis('tight')
plt.show()

# %%
Z = np.cos(2*np.sqrt(X**2 + Y**2)) 
plt.contour( X,Y,Z, 30 )
plt.show()

# %%
plt.contourf( X,Y,Z, 20, cmap = 'prism' )
plt.colorbar()
plt.show()

# %%
# Generate a default contour map of the array Z
plt.subplot(2,2,1)
plt.contour( X, Y, Z )

# Generate a contour map with 20 contours
plt.subplot(2,2,2)
plt.contour( X, Y, Z, 20 )

# Generate a default filled contour map of the array Z
plt.subplot(2,2,3)
plt.contourf( X, Y, Z, 20 )

# Generate a default filled contour map with 20 contours
plt.subplot(2,2,4)
plt.contourf( X, Y, Z, 20 )

# Improve the spacing between subplots
plt.tight_layout()

# Display the figure
plt.show()

# %%
# Create a filled contour plot with a color map of 'viridis'
plt.subplot(2,2,1)
plt.contourf(X,Y,Z,20, cmap='viridis')
plt.colorbar()
plt.title('Viridis')

# Create a filled contour plot with a color map of 'gray'
plt.subplot(2,2,2)
plt.contourf(X,Y,Z,20, cmap='gray')
plt.colorbar()
plt.title('Gray')

# Create a filled contour plot with a color map of 'autumn'
plt.subplot(2,2,3)
plt.contourf(X,Y,Z,20, cmap='autumn')
plt.colorbar()
plt.title('Autumn')

# Create a filled contour plot with a color map of 'winter'
plt.subplot(2,2,4)
plt.contourf(X,Y,Z,20, cmap='winter')
plt.colorbar()
plt.title('Winter')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing Bivariate Distributions

# %% [markdown]
# Histograms 1D
# * choose bins (intervals)
# * count realizations within bins & plot
#
# Histograms 2D
# * different shapes available for binning points
# * common choices: rectangle & hexagons

# %%
hp = np.array([ 88, 193,  60,  98,  78, 100,  75,  76, 130, 140,  52,  88,  84,
       148, 150, 130,  58,  82,  65, 110,  95, 110, 140, 170,  78,  90,
        96,  95, 110,  75, 132, 150,  83,  85,  86,  75, 140, 139,  70,
        52,  60,  84, 138, 180,  65,  67,  97, 150,  70, 100, 180, 129,
        95,  90,  83,  75, 100,  85, 112,  67,  65,  88, 100,  75, 100,
        70, 145, 110, 210,  80, 145,  69, 150, 198, 120,  92,  90, 115,
        95,  75,  76,  67,  71, 115,  84,  91, 150, 215,  67, 175,  60,
       175, 110,  95,  68, 150,  67,  95, 110, 105, 102, 110,  89,  66,
        88,  75,  78, 105,  70, 103,  60, 150,  72, 170,  90, 110,  58,
       152, 145, 139,  83,  69, 150,  67,  80,  71,  46, 105,  90, 110,
       175,  80,  74, 150, 150,  65, 100,  48, 105,  90,  48, 105, 105,
        88, 100,  75, 113, 190,  92,  80, 165, 180,  71,  97,  72, 105,
        90,  75,  88, 155,  68,  90,  84,  87, 112,  87, 125, 108, 142,
        97, 105,  75, 137, 150,  88, 145,  63,  95, 140,  88,  85,  70,
        85, 115,  86,  79, 120, 120,  65, 110, 220, 115, 170, 100,  90,
       225,  85,  65,  97,  90,  90,  49, 110,  70,  92,  53, 100, 190,
        63,  90,  67,  65,  75, 100, 110,  60,  93,  88, 150, 100, 150,
        88, 225,  68,  70, 208, 105,  74,  90, 110,  72,  97,  88,  88,
       129,  85,  86, 150,  70,  48,  77,  65, 175,  90, 150, 110, 130,
        53,  65, 158,  95,  61, 215, 100, 145,  68, 150,  88,  67, 105,
       175, 160,  74, 135, 100,  67, 198, 180, 215, 100, 225, 155, 170,
        81,  85,  95,  80,  92,  70, 149,  84,  97,  52,  72,  85,  52,
        95,  71, 140, 100,  96, 150,  75, 107, 110,  75,  97, 133,  70,
        67, 112, 145, 115,  98,  70,  78, 230,  63,  76, 105,  95,  62,
       165, 165, 160, 190,  95, 180,  78, 120,  80,  75,  68,  67,  95,
       140, 110,  72, 150,  95,  54, 153, 130, 170,  86,  97,  90, 145,
        86,  79, 165,  83,  64,  92,  72, 140, 150,  96, 150,  80, 130,
       100, 125,  90,  94,  76,  90, 150,  97,  85,  81,  78,  46,  84,
        70, 153, 116, 100, 167,  88,  88,  88, 200, 125,  92, 110,  69,
        67,  90, 150,  90,  71, 105,  62,  88, 122,  65,  88,  90,  68,
       110,  88])


mpg = np.array([18. ,  9. , 36.1, 18.5, 34.3, 32.9, 32.2, 22. , 15. , 17. , 44. ,
       24.5, 32. , 14. , 15. , 13. , 36. , 31. , 32. , 21.5, 19. , 17. ,
       16. , 15. , 23. , 26. , 32. , 24. , 21. , 31.3, 32.7, 15. , 23. ,
       17.6, 28. , 24. , 14. , 18.1, 36. , 29. , 35.1, 36. , 16.5, 16. ,
       29.9, 31. , 27.2, 14. , 32.1, 15. , 12. , 17.6, 25. , 28.4, 29. ,
       30.9, 20. , 20.8, 22. , 38. , 31. , 19. , 16. , 25. , 22. , 26. ,
       13. , 19.9, 11. , 28. , 15.5, 26. , 14. , 12. , 24.2, 25. , 22.5,
       26.8, 23. , 26. , 30.7, 31. , 27.2, 21.5, 29. , 20. , 13. , 14. ,
       38. , 13. , 24.5, 13. , 25. , 24. , 34.1, 13. , 44.6, 20.5, 18. ,
       23.2, 20. , 24. , 25.5, 36.1, 23. , 24. , 18. , 26.6, 32. , 20.3,
       27. , 17. , 21. , 13. , 24. , 17. , 39.1, 14.5, 13. , 20.2, 27. ,
       35. , 15. , 36.4, 30. , 31.9, 26. , 16. , 20. , 18.6, 14. , 25. ,
       33. , 14. , 18.5, 37.2, 18. , 44.3, 18. , 28. , 43.4, 20.6, 19.2,
       26.4, 18. , 28. , 26. , 13. , 25.8, 28.1, 13. , 16.5, 31.5, 24. ,
       15. , 18. , 33.5, 32.4, 27. , 13. , 31. , 28. , 27.2, 21. , 19. ,
       25. , 23. , 19. , 15.5, 23.9, 22. , 29. , 14. , 15. , 27. , 15. ,
       30.5, 25. , 17.5, 34. , 38. , 30. , 19.8, 25. , 21. , 26. , 16.5,
       18.1, 46.6, 21.5, 14. , 21.6, 15.5, 20.5, 23.9, 12. , 20.2, 34.4,
       23. , 24.3, 19. , 29. , 23.5, 34. , 37. , 33. , 18. , 15. , 34.7,
       19.4, 32. , 34.1, 33.7, 20. , 15. , 38.1, 26. , 27. , 16. , 17. ,
       13. , 28. , 14. , 31.5, 34.5, 11. , 16. , 31.6, 19.1, 18.5, 15. ,
       18. , 35. , 20.2, 13. , 31. , 22. , 11. , 33.5, 43.1, 25.4, 40.8,
       14. , 29.8, 16. , 20.6, 18. , 33. , 31.8, 13. , 20. , 32. , 13. ,
       23.7, 19.2, 37. , 18. , 19. , 32.3, 18. , 13. , 12. , 36. , 18.2,
       19. , 30. , 15. , 11. , 10. , 16. , 14. , 16.9, 13. , 25. , 21. ,
       21.1, 26. , 28. , 29. , 16. , 26.6, 19. , 32.8, 22. , 19. , 31. ,
       23. , 29.5, 17.5, 19. , 24. , 14. , 28. , 21. , 22.4, 36. , 18. ,
       16.2, 39.4, 30. , 18. , 17.5, 28.8, 22. , 34.2, 30.5, 16. , 38. ,
       41.5, 27.9, 22. , 29.8, 17.7, 15. , 14. , 15.5, 17.5, 12. , 29. ,
       15.5, 35.7, 26. , 30. , 33.8, 18. , 13. , 20. , 32.4, 16. , 27.5,
       23. , 14. , 17. , 16. , 23. , 24. , 27. , 15. , 27. , 28. , 14. ,
       33.5, 39. , 24. , 26.5, 19.4, 15. , 25.5, 14. , 27.4, 13. , 19. ,
       17. , 28. , 22. , 30. , 18. , 14. , 22. , 23.8, 24. , 26. , 26. ,
       30. , 29. , 14. , 25.4, 19. , 12. , 20. , 27. , 22.3, 10. , 19.2,
       26. , 16. , 37.3, 26. , 20.2, 13. , 21. , 25. , 20.5, 37.7, 36. ,
       20. , 37. , 18. , 27. , 29.5, 17.5, 25.1])

# %%
#histogram 1D
counts, bins, patches = plt.hist( hp, bins=25 )
plt.show()

# %%
#histogram 2D
plt.subplot( 1,2,1 )
plt.hist2d( hp, mpg, bins = ( 20, 20 ), range=((40, 235), (8, 48)) )
plt.colorbar()
plt.xlabel( 'weight ($\\mathrm{kg}$)' )
plt.ylabel( 'acceleration ($\\mathrm{ms}^{-2})$' )


plt.subplot( 1,2,2 )
plt.hexbin( hp, mpg, gridsize = ( 15,12 ), extent = ( 40, 235, 8, 48) )
plt.colorbar()
plt.xlabel( 'weight ($\\mathrm{kg}$)' )
plt.ylabel( 'acceleration ($\\mathrm{ms}^{-2}$)' )


plt.tight_layout()
plt.show()
